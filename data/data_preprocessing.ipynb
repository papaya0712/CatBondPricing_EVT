# %%
import pandas as pd
import csv


csv_path = r"C:\Users\nikla\Desktop\github_projects\CatBondPricing_EVT\data\earthquakes_us_1950-1987.feather"
out_path = r"CatBondPricing_EVT\data"

raw_data = pd.read_feather(csv_path) 
raw_data
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0      1950-01-03T11:26:30.040Z  33.940667 -115.888167   6.000  3.37      ml
# 1      1950-01-05T13:45:48.730Z  33.574833 -119.321500   6.000  3.11      ml
# 2      1950-01-07T09:37:33.670Z  31.983500 -116.819167   6.000  4.07      ml
# 3      1950-01-09T13:24:56.940Z  34.066167 -116.959000   0.040  3.78      ml
# 4      1950-01-09T21:40:35.740Z  33.752333 -116.018667   6.000  3.08      ml
# ...                         ...        ...         ...     ...   ...     ...
# 19995  1987-09-15T10:48:37.350Z  36.281833 -120.402667   9.403  3.26      md
# 19996  1987-09-16T00:07:34.340Z  40.322833 -124.621333  19.615  3.40      ml
# 19997  1987-09-16T13:22:00.120Z  31.651000 -115.795000   5.842  3.11      mc
# 19998  1987-09-16T20:10:42.200Z  49.083000 -122.709000   1.000  3.00      ml
# 19999  1987-09-17T08:31:26.630Z  41.186500 -113.141000  13.670  3.67      ml
#
# ...

# %%
data = raw_data
data = data[data["place"].str.endswith((", CA", ", California"), na=False)]
data = data.reset_index(drop=True)
data["time"] = pd.to_datetime(data["time"])

data = data.drop(columns=
                     ["type", "status", "updated", "magNst", 
                      "locationSource", "magSource", "depthError", 
                      "horizontalError", "nst", "gap", "place"]

                     )

data
# Out:
#                                   time   latitude   longitude   depth   mag  \
# 0     1950-01-03 11:26:30.040000+00:00  33.940667 -115.888167   6.000  3.37
# 1     1950-01-05 13:45:48.730000+00:00  33.574833 -119.321500   6.000  3.11
# 2     1950-01-09 13:24:56.940000+00:00  34.066167 -116.959000   0.040  3.78
# 3     1950-01-09 21:40:35.740000+00:00  33.752333 -116.018667   6.000  3.08
# 4     1950-01-11 21:41:34.340000+00:00  33.945667 -118.179833   3.440  3.89
# ...                                ...        ...         ...     ...   ...
# 13524 1987-09-13 04:14:18.360000+00:00  39.784333 -121.868667  24.069  3.27
# 13525 1987-09-14 07:25:43.920000+00:00  39.473000 -122.909667  -1.157  3.00
# 13526 1987-09-15 02:06:42.730000+00:00  36.118000 -119.991333  24.016  3.40
# 13527 1987-09-15 10:48:37.350000+00:00  36.281833 -120.402667   9.403  3.26
# 13528 1987-09-16 00:07:34.340000+00:00  40.322833 -124.621333  19.615  3.40
#
#       magType     dmin   rms net          id  magError
# ...

# %%
data["mag"].describe()

for u in [4.0, 4.5, 5.0, 5.5, 6.0]:
    n = (data["mag"] >= u).sum()
    print(f"M >= {u}: {n}")
# Out:
# M >= 4.0: 1501
# M >= 4.5: 510
# M >= 5.0: 155
# M >= 5.5: 47
# M >= 6.0: 10
